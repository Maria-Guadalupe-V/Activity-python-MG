# %%
import requests
print("Lista de Reproducción\n")
# Referencia: https://www.deezer.com/en/channels/explore
print("Ingresa la palabra que te gustaría")
print("Ejemplo: 'rock', y obtendrás un playlist de canciones o artistas que incluyan la palabra rock")
word_to_search = input()
url = "https://deezerdevs-deezer.p.rapidapi.com/search"
querystring = {"q":word_to_search}
headers = {
 "X-RapidAPI-Key": "3ed98f551fmshe4e6260228c4eadp13db17jsn8c893e1194da",
 "X-RapidAPI-Host": "deezerdevs-deezer.p.rapidapi.com"
}
response = requests.request("GET", url, headers=headers, params=querystring).json()
for element in response['data']:
 my_list = [element['title'], element['artist']['name']]
 my_tuple = tuple(my_list)
 print(my_tuple)
# Out:
# Lista de Reproducción
#
# Ingresa la palabra que te gustaría
# Ejemplo: 'rock', y obtendrás un playlist de canciones o artistas que incluyan la palabra rock
#  k-pop
# ('Pink Venom', 'BLACKPINK')
# ('Briller (Golden - version française)', 'HUNTR/X')
# ('Takedown', 'HUNTR/X')
# ('Golden (Sing-Along)', 'HUNTR/X')
# ('K-POP', 'The Weeknd')
# ('TAKEDOWN (JEONGYEON, JIHYO, CHAEYOUNG)', 'TWICE')
# ('Strategy', 'TWICE')
# ('KPop Demon Hunters | Golden', 'Just Let That Sh*t Go')
# ('Golden (Acapella)', 'HUNTR/X')
# ('Soda Pop (Metal Version)', 'Jonathan Young')
# ('KPop Demon Hunters | Saja Boys (Your Idol)', 'Just Let That Sh*t Go')
# ('KPop Demon Hunters Wedding Song', 'DJ GG')
# ('K-Pop', 'Lacrim')
# ('Soda Pop', 'Clay K Slider')
# ('낙원', 'K-Pop')
# ('Briller', 'Jungeli')
# ('Game', 'K-Pop')
# ('K-POP (Instrumental)', 'The Weeknd')
# ('Y', 'K-Pop')
# ('K-pop', 'MAMA RUSSIA')
# ('그림자', 'K-Pop')
# ('The K-Pop Club', 'K-Pop')
# ('시나브로', 'K-Pop')
# ("Stayin' Inside", 'Samich')
# ('K-POP', 'Blitzers')
