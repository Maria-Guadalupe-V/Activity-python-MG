# %%
import time

def countdown(time_sec):
    while time_sec:
        mins, secs = divmod(time_sec, 60)
        timeformat = '{:02d}:{:02d}'.format(mins, secs)
        print(timeformat, end='\r')
        time.sleep(1)
        time_sec -= 1
    print("stop")
countdown(90)

def countup(time_sec):
    contador = 0;
    while  contador <= time_sec:
        mins, secs = divmod(contador, 60)
        timeformat = '{:02d}:{:02d}'.format(mins, secs)
        print(timeformat, end='\r')
        time.sleep(1)
        contador += 1
    print("stop")
countup(90)
# Out:
# stop1
# stop0
