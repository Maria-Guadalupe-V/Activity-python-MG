# %% [markdown]
# ## El comando SSH
# SSH - Secure Shell
# Puendes pensarlo como la manera de acceder a otra computadora
#
# Ejemplo:
# ssh -i directory/key.pem user@ipaddress

# %% [markdown]
# ## Corriendo linux en un contenedor
# https://github.com/nickjj/docker-django-example
#
# git clone https://github.com/nickjj/docker-django-example hellodjango
#
# cd hellodjango
#
# cp .env.example .env
#
# docker compose up --build
#
# docker exec -it hellodjango-web-1 bash
#
# cat /etc/issue

# %% [markdown]
# ## Principales carpetas en Linux

# %%
from IPython import display
display.Image(filename="C:/Users/Sony Vaio/Pictures/photos/arbol_linux.jpg")

# %% [markdown]
# ## Comandos esenciales
# pwd - print working directory - imprime la ruta de el directorio en el que estamos
#
# ls - list - lista los archivos y carpetas en el directorio en el que estamos
#
# cd - change directory - cambiar de directorio/carpeta (usar .. para carpeta anterior/padre)
#
# clear - limpiar la terminal
#
# mkdir - make directory - crear una carpeta
#
# touch - crear archivos dentro de la carpeta actual
#
# cp - copy - copiar
#
# mv - move - mover o renombrar
#
# rm - remove - eliminar (usar -r para eliminar carpetas)

# %% [markdown]
# ## Introducción a Django
#
# ¿Qué es Django?
# - "Web framework for perfectionist with deadlines"
# - Motiva el desarrollo rápido de sitios web de forma limpia y estructurada
# - Es usado por Instagram, YouTube, Spotify y muchas otras Empresas
#
# ¿Por qué lo necesitamos?
# - Con HTML, CSS, JS podemos crear sitios web esáticos (Frontend)
# - Pero además queremos crear comportamientos a la medida haciendo uso de bases de datos (Backend)
# - Django nos ayuda a cubrir todo esto

# %% [markdown]
# ## Proyecto y Aplicación

# %% [markdown]
# pip freeze
# amqp==5.3.1
# asgiref==3.11.0
# billiard==4.2.1
# celery==5.6.3
# click==8.1.8
# click-didyoumean==0.3.1
# click-plugins==1.1.1
# click-repl==0.3.0
# Django==6.1
# django-debug-toolbar==7.0.0
# gunicorn==26.0.0
# kombu==5.6.1
# packaging==24.2
# prompt_toolkit==3.0.50
# psycopg==3.3.4
# python-dateutil==2.9.0.post0
# redis==8.1.0
# ruff==0.16.1
# setuptools==83.0.0
# six==1.17.0
# sqlparse==0.5.3
# tzdata==2025.2
# tzlocal==5.3.1
# vine==5.1.0
# wcwidth==0.2.13
# whitenoise==6.12.0.0
# ruff==0.16.1
# s
# etuptools==8
# 3.0.0
# six==1.17
# .0
# sqlparse==0
# .5.3
# tzdata==2
# 025.2
# tzloc
# al==5.3.1
# vine/n=
# =5.1.0
# wcwidth==0/n2.13
# whitenoise==6.12.0

# %% [markdown]
# ## Migraciones
#
# (Los cambios a la base de datos, base de datos es donde almacenamos la información)
#
# En este proyecto:
#
# ./run manage migrate
#
# En django standard:
#
# python manage.py migrate
#
# Ver el sitio web: http://localhost:8000/

# %% [markdown]
# ## Estructura de un Proyecto en Django

# %% [markdown]
# ### Archivos de proyecto
# - manage.py: es un archivo que contiene muchas funciones que te permiten interactuar con Django
# - config/__init__.py: un archivo vacío que le informa a Python que este directorio/carpeta debería ser considerado como un paquete de Python
# - config/settings.py: Configuración o ajustes para el proyecto en django
# - config/urls.py: las declaraciones de los urls para el proyecto django. Es como una tabla de contenidos con los endpoints del sitio web
# - config/asgi.py: un punto de entrada para servidores web compatibles con ASGI para desplegar el proyecto
# - config/wasgi.py: un punto de entrada para servidores web compatibles con ASGI para desplegar el proyecto

# %% [markdown]
# ### Archivos de Aplicación

# %% [markdown]
# - adimin.py: registrar tus modelos relacionados con el django admin
# - apps.py: contiene el código de la configuración de la app
# - models.py: define tus modelos aquí. Son las tablas en la base de datos para almacenar la información y definir sus relaciones
# - tests.py: escribir tests para la app
# - views.py: definir la información que será mandada a los templates del frontend

# %% [markdown]
# ## Has tus primeros cambios visibles en el proyecto

# %% [markdown]
# import os
#
# from django import get_version
# from django.conf import settings
# from django.shortcuts import render
#
#
# def home(request):
#     context = {
#         "debug": settings.DEBUG,
#         "django_ver": get_version() + "PROBANDO CAMBIOS",
#         "python_ver": os.environ["PYTHON_VERSION"] + "CAMBIOS",
#     }
#
#     return render(request, "pages/home.html", context)
