# %% [markdown]
# # Operadores y Tipos de Operadores

# %% [markdown]
# ¿QUE SON LOS OPERADORES?
# - Son un conjunto de simbolos para un lenguaje de programacionn
# - pueden decirle al compilador o interprete que ejecute ciertas acciones para producir un resultado final
# - pueden ser usados para aplicar operaciones en variables o valores
# - Pueden ser clasificados segunsu tipo (aritmeticos, relacionales de asignacion, logicos, afiliacion y de identidad)

# %% [markdown]
# Tipos de opeadores:
# - Aritmeticos
# - Relacionales
# - De Asignacion
# - Logicos
# - De Afiliacion
# - De Identidad

# %% [markdown]
# ### Operadores aritmeticos
# - "+": suma
# - "-": resta
# - "*": multiplicacion
# - "/": divicion
# - "//": divicion con reddondeo hacia abajo
# - "**": exponente

# %%
# "+": suma
num_1 = 500
num_2 = 300
print("El resultado de num_1 + num_2 es:" ,num_1 + num_2)
# Out:
# El resultado de num_1 + num_2 es: 800

# %%
# "+": suma
num_1 = 200
num_2 = 900
print("El resultado de num_1 + num_2 es:" ,num_1 + num_2)
# Out:
# El resultado de num_1 + num_2 es: 1100

# %%
# "-": resta
num_1 = 500
num_2 = 300
print("El resultado de num_1 - num_2 es:" ,num_1 - num_2)
# Out:
# El resultado de num_1 - num_2 es: 200

# %%
# "-": resta
num_1 = 200
num_2 = 900
print("El resultado de num_1 - num_2 es:" ,num_1 - num_2)
# Out:
# El resultado de num_1 - num_2 es: -700

# %%
# *: multiplicacion
num_1 = 500
num_2 = 300
print("El resultado de num_1 * num_2 es:" ,num_1 * num_2)
# Out:
# El resultado de num_1 * num_2 es: 150000

# %%
# *: multiplicacion
num_1 = 200
num_2 = 900
print("El resultado de num_1 * num_2 es:" ,num_1 * num_2)
# Out:
# El resultado de num_1 * num_2 es: 180000

# %%
# /: division
num_1 = 500
num_2 = 300
print("El resultado de num_1 / num_2 es:" ,num_1 / num_2)
# Out:
# El resultado de num_1 / num_2 es: 1.6666666666666667

# %%
# /: divisionnum_1 = 500
num_1 = 200
num_2 = 900
print("El resultado de num_1 / num_2 es:" ,num_1 / num_2)
# Out:
# El resultado de num_1 / num_2 es: 0.2222222222222222

# %%
# //: division con redondeo hacia abajo, la parte entera de el resultado
num_1 = 500
num_2 = 300
print("El resultado de num_1 // num_2 es:" ,num_1 // num_2)
# Out:
# El resultado de num_1 // num_2 es: 1

# %%
# //: division con redondeo hacia abajo, la parte entera de el resultado
num_1 = 200
num_2 = 900
print("El resultado de num_1 // num_2 es:" ,num_1 // num_2)
# Out:
# El resultado de num_1 // num_2 es: 0

# %%
# "**": exponente (elevar a un exponente)
num_1 = 2
num_2 = 5
print("El resultado de num_1 ** num_2 es:" ,num_1 ** num_2) # 2*2*2*2*2
# Out:
# El resultado de num_1 ** num_2 es: 32

# %%
# "**": exponente (elevar a un exponente)
num_1 = 3
num_2 = 3
print("El resultado de num_1 ** num_2 es:" ,num_1 ** num_2) # 3*3*3
# Out:
# El resultado de num_1 ** num_2 es: 27

# %% [markdown]
# ### Operadores Relacionales

# %% [markdown]
# ¿Que son los Operadores Relacionales?
# - Son tambien conocidos como Operadores de Comparacion
# - Regresan un valor booleano (Verdadero o Faso)
# - En Python son usados para comparar o relacinar los valores
# - Verdadero/True es el resultado cuando la condicion es exitosa
# - Falso/False, es el resultado cuando la condicion no se cumple
# - Estos Operadores se encargan de las operaciones de comparacion

# %% [markdown]
# Tipos de Operadores Relacionales
# - "==": Igualn a
# - "!=": Diferente a
# - ">": mayor que
# - ">=": mayor o igual que
# - "<" : menor que
# - "<=": menor o igual que

# %%
# "==": Igualn a

# %%
num_1 = 570 # asignacion
num_2 = 420
print ("El resultado de num_1==num_2 es: ",num_1==num_2)
# Out:
# El resultado de num_1==num_2 es:  False

# %%
num_1 = 570 # asignacion
num_2 = 570
print ("El resultado de num_1==num_2 es: ",num_1==num_2)
# Out:
# El resultado de num_1==num_2 es:  True

# %%
str_1 = "Backend Python " # asignacion
str_2 = "Backend Python " # asignacion
print ("El resultado de str_1==str_2 es: ",str_1==str_2)
# Out:
# El resultado de str_1==str_2 es:  True

# %%
str_1 = "Backend Python " # asignacion
str_2 = "Backend python " # asignacion
print ("El resultado de str_1==str_2 es: ",str_1==str_2)
# Out:
# El resultado de str_1==str_2 es:  False

# %%
# "!=" : diferente a

# %%
num_1 = 570 # asignacion
num_2 = 420
print ("El resultado de num_1!=num_2 es: ",num_1!=num_2)
# Out:
# El resultado de num_1!=num_2 es:  True

# %%
num_1 = 570 # asignacion
num_2 = 570
print ("El resultado de num_1!=num_2 es: ",num_1!=num_2)
# Out:
# El resultado de num_1!=num_2 es:  False

# %%
str_1 = "Backend Python " # asignacion
str_2 = "Backend Python " 
print ("El resultado de str_1!=str_2 es: ",str_1!=str_2)
# Out:
# El resultado de str_1!=str_2 es:  False

# %%
str_1 = "Backend Python " # asignacion
str_2 = "Backend python " # asignacion
print ("El resultado de str_1!=str_2 es: ",str_1!=str_2)
# Out:
# El resultado de str_1!=str_2 es:  True

# %%
# ">" : mayor que

# %%
num_1 = 570 # asignacion
num_2 = 420
print ("El resultado de num_>num_2 es: ",num_1>num_2)
# Out:
# El resultado de num_>num_2 es:  True

# %%
num_1 = 570 # asignacion
num_2 = 570
print ("El resultado de num_>num_2 es: ",num_1>num_2)
# Out:
# El resultado de num_>num_2 es:  False

# %%
num_1 = 570 # asignacion
num_2 = 890
print ("El resultado de num_>num_2 es: ",num_1>num_2)
# Out:
# El resultado de num_>num_2 es:  False

# %%
# ">=" : mayor o igual que

# %%
num_1 = 570 # asignacion
num_2 = 420
print ("El resultado de num_>=num_2 es: ",num_1>=num_2)
# Out:
# El resultado de num_>=num_2 es:  True

# %%
num_1 = 570 # asignacion
num_2 = 570
print ("El resultado de num_>=num_2 es: ",num_1>=num_2)
# Out:
# El resultado de num_>=num_2 es:  True

# %%
num_1 = 570 # asignacion
num_2 = 890
print ("El resultado de num_>=num_2 es: ",num_1>=num_2)
# Out:
# El resultado de num_>=num_2 es:  False

# %%
# "<" : menor que

# %%
num_1 = 570 # asignacion
num_2 = 420
print ("El resultado de num_<num_2 es: ",num_1<num_2)
# Out:
# El resultado de num_<num_2 es:  False

# %%
num_1 = 570 # asignacion
num_2 = 570
print ("El resultado de num_<num_2 es: ",num_1<num_2)
# Out:
# El resultado de num_<num_2 es:  False

# %%
num_1 = 570 # asignacion
num_2 = 890
print ("El resultado de num_<num_2 es: ",num_1<num_2)
# Out:
# El resultado de num_<num_2 es:  True

# %%
# "<=" : menor o igual que

# %%
num_1 = 570 # asignacion
num_2 = 420
print ("El resultado de num_<=num_2 es: ",num_1<=num_2)
# Out:
# El resultado de num_<=num_2 es:  False

# %%
num_1 = 570 # asignacion
num_2 = 570
print ("El resultado de num_<=num_2 es: ",num_1<=num_2)
# Out:
# El resultado de num_<=num_2 es:  True

# %%
num_1 = 570 # asignacion
num_2 = 890
print ("El resultado de num_<=num_2 es: ",num_1<=num_2)
# Out:
# El resultado de num_<=num_2 es:  True

# %% [markdown]
# ### Operadores de Asignación

# %% [markdown]
# ¿Que son los Operadoress de Asignacion?
# - En python son usados para asignar valores y variables
# - Incluyen al operador de asignacion que es el signo de igual (=)

# %% [markdown]
# Tipos de Operadores de Asignación
# - "=": Operador de Asignación
# - "+=": Sumar y Asignar
# - "-=": Restar y Asignar
# - "*=": Multiplicar y Asignar
# - "/=": Dividir y Asignar
# - "//=": Dividir con redondeo hacia abajo y Asignar
# - "%=": Módulo y Asignar
# -  "**=": Exponente y Asignar

# %%
# "=": Operador de Asignación

# %%
num_1 = 20
num_2 = 3

# %%
# "+=": Sumar y Asignar

# %%
num_1 = 20
num_2 = 3
print ("num_1 antes de la operacion: ",num_1)
num_1 +=  num_2 # num_1 = num_1 + num_2
print ("num_1 despues de la operacion: ",num_1)
# Out:
# num_1 antes de la operacion:  20
# num_1 despues de la operacion:  23

# %%
num_1 = 20
num_2 = 3
print ("num_1 antes de la operacion: ",num_1)
num_1 -=  num_2 # num_1 = num_1 - num_2
print ("num_1 despues de la operacion: ",num_1)
# Out:
# num_1 antes de la operacion:  20
# num_1 despues de la operacion:  17

# %%
num_1 = 20
num_2 = 3
print ("num_1 antes de la operacion: ",num_1)
num_1 *=  num_2 # num_1 = num_1 * num_2
print ("num_1 despues de la operacion: ",num_1)
# Out:
# num_1 antes de la operacion:  20
# num_1 despues de la operacion:  60

# %%
num_1 = 20
num_2 = 3
print ("num_1 antes de la operacion: ",num_1)
num_1 /=  num_2 # num_1 = num_1 / num_2
print ("num_1 despues de la operacion: ",num_1)
# Out:
# num_1 antes de la operacion:  20
# num_1 despues de la operacion:  6.666666666666667

# %%
num_1 = 20
num_2 = 3
print ("num_1 antes de la operacion: ",num_1)
num_1 //=  num_2 # num_1 = num_1 +// num_2
print ("num_1 despues de la operacion: ",num_1)
# Out:
# num_1 antes de la operacion:  20
# num_1 despues de la operacion:  6

# %%
# % - Módulo - El numero que queda despues de haber dividido, residuo
num_1 = 20
num_2 = 3
print ("num_1 antes de la operacion: ",num_1)
num_1 %=  num_2 # num_1 = num_1 % num_2
print ("num_1 despues de la operacion: ",num_1)
# Out:
# num_1 antes de la operacion:  20
# num_1 despues de la operacion:  2

# %%
# exponente
num_1 = 20
num_2 = 3
print ("num_1 antes de la operacion: ",num_1)
num_1 **=  num_2 # num_1 = num_1 ** num_2
# 20 * 20 * 20
print ("num_1 despues de la operacion: ",num_1)
# Out:
# num_1 antes de la operacion:  20
# num_1 despues de la operacion:  8000

# %% [markdown]
# ### Operadores Lógicos

# %% [markdown]
# ¿Que son los Operadores Lógicos?
# - Son usados principalmente para declaraciones condicionales
# - Son indicadores estructurales
# - También se les conoce como Conectores Lógicos
# - Hay 3 tipos de Operadores Lógicos:
#     -  AND (y) - regresa True/Verdadero si ambas operaciones son verdaderas
#     -  OR (o) - regresa True/Verdarero si por lo menos una de las operaciones es verdadera
#     -  NOT (lo opuesto) - regresa True/Verdadero si la operación es False/Falso

# %%
# AND (y) 
# Todas las condiciones deben ser Verdaderas

# %%
num_1 = 11
num_2 = 55
# num_1<=num_2: True/Verdarero
# num_1!=num_2: True/Verdadero
print ("num_1<=num_2 and num_1!=num_2",num_1<=num_2 and num_1!=num_2)
# Out:
# num_1<=num_2 and num_1!=num_2 True

# %%
num_1 = 11
num_2 = 11
# num_1<=num_2: True/Verdarero
# num_1!=num_2: False/Falso
print ("num_1<=num_2 and num_1!=num_2",num_1<=num_2 and num_1!=num_2)
# Out:
# num_1<=num_2 and num_1!=num_2 False

# %%
num_1 = 11
num_2 = 55
# num_1<=num_2: True/Verdarero
# num_1!=num_2: True/Verdadero
# num_1>10: True/Verdadero
print ("num_1<=num_2 and num_1!=num_2",num_1<=num_2 and num_1!=num_2 and num_1>10)
# Out:
# num_1<=num_2 and num_1!=num_2 True

# %%
num_1 = 11
num_2 = 11
# num_1<=num_2: True/Verdarero
# num_1!=num_2: False/Falso
# num_1>10: True/Verdadero
print ("num_1<=num_2 and num_1!=num_2",num_1<=num_2 and num_1!=num_2 and num_1>10)
# Out:
# num_1<=num_2 and num_1!=num_2 False

# %%
# OR (o) - con que una de las condiciones se cumpla regresa True

# %%
num_1 = 11
num_2 = 55
# num_1<=num_2: True/Verdarero
# num_1!=num_2: True/Verdadero
print ("num_1<=num_2 and num_1!=num_2",num_1<=num_2 or num_1!=num_2)
# Out:
# num_1<=num_2 and num_1!=num_2 True

# %%
num_1 = 11
num_2 = 11
# num_1<=num_2: True/Verdarero
# num_1!=num_2: False/Falso
print ("num_1<=num_2 and num_1!=num_2",num_1<=num_2 or num_1!=num_2)
# Out:
# num_1<=num_2 and num_1!=num_2 True

# %%
num_1 = 11
num_2 = 55
# num_1<=num_2: True/Verdarero
# num_1!=num_2: True/Verdadero
# num_1>10: True/Verdadero
print ("num_1<=num_2 and num_1!=num_2",num_1<=num_2 or num_1!=num_2 or num_1>10)
# Out:
# num_1<=num_2 and num_1!=num_2 True

# %%
num_1 = 11
num_2 = 11
# num_1<=num_2: True/Verdarero
# num_1!=num_2: False/Falso
# num_1>10: True/Verdadero
print ("num_1<=num_2 and num_1!=num_2",num_1<=num_2 or num_1!=num_2 or num_1>10)
# Out:
# num_1<=num_2 and num_1!=num_2 True

# %%
# Not (lo opuesto) 
# La condición deve ser Falsa

# %%
num_1 = 11
num_2 = 55
# num_1<=num_2: True/Verdadero
print("not num_1<=num_2 = 55",not num_1<=num_2 )
# Out:
# not num_1<=num_2 = 55 False

# %%
num_1 = 11
num_2 = 55
# num_1!=num_2: True/Verdadero
print("not num_1!=num_2 = 55",not num_1!=num_2 )
# Out:
# not num_1!=num_2 = 55 False

# %%
num_1 = 11
num_2 = 55
# num_1>num_2: False/Falso
print("not num_1>num_2 = 55",not num_1>num_2)
# Out:
# not num_1>num_2 = 55 True

# %% [markdown]
# ### Operadores de Afiliación

# %% [markdown]
# ¿Qué son los Operadores de Afiliación?
# - Son usados para validar los elementos en listas cadenas y tuplas
# - Validan si una variable esta presente en una secuencia
# - Regresan un valor booleano con el resultado True/False
# - Regresan True/Verdadero si el valor esta presente en la secuencia
# - Regresan False/Falso si el valor no esta presente en la secuencia
# - Hay dos opradores de afiliación:
#      - IN - el valor esta en la secuencia
#      - NOT IN - el valor no esta en la secuencia

# %%
# IN: ¿El valor esta presente en la secuencia?

# %%
my_string = "Backend Python"
print ("'a' in my_string",'a' in my_string)
# Out:
# 'a' in my_string True

# %%
my_string = "Backend Python"
print ("'i' in my_string",'i' in my_string)
# Out:
# 'i' in my_string False

# %%
my_list = [1, 154, 321, 22, 11]
print ("5 in my_list", 5 in my_list)
# Out:
# 5 in my_list False

# %%
my_list = [1, 154, 321, 22, 11, 5, 11, 22, 5, 1]
print ("5 in my_list", 5 in my_list)
# Out:
# 5 in my_list True

# %%
my_list
# Out:
# [1, 154, 321, 22, 11, 5, 11, 22, 5, 1]

# %%
my_set = {1, 154, 321, 22, 11, 5, 11, 22, 5, 1}
print ("5 in my_set", 5 in my_set)
# Out:
# 5 in my_set True

# %%
my_set
# Out:
# {1, 5, 11, 22, 154, 321}

# %%
# NOT IN: ¿El valor NO esta persente en la secuencia?

# %% [markdown]
# my_string = "Backend Python"
# print ("'a' not  in my_string",'a' not in my_string)

# %%
my_string = "Backend Python"
print ("'i' not  in my_string",'i' not in my_string)
# Out:
# 'i' not  in my_string True

# %%
my_list = [1, 154, 321, 22, 11]
print ("5 not in my_list", 5 not in my_list)
# Out:
# 5 not in my_list True

# %%
my_list = [1, 154, 321, 22, 11, 5]
print ("5 not in my_list", 5 not in my_list)
# Out:
# 5 not in my_list False

# %%
my_set = {1, 154, 321, 22, 11, 5, 11, 22, 5, 1}
print ("5 not in my_set", 5 not in my_set)
# Out:
# 5 not in my_set False

# %% [markdown]
# ### Operadores de Identidad

# %% [markdown]
# ¿Qué son los Operadores de Identidad?
# - Son usados para comparar la ubicación en memoria de dos objetos
# - Se utilizan para validar si los valores comparten el mismo espacio en memoria o no
# - Regresa True/Verdadero si lo comparten, y False/Falso  si no lo comparten
# - Hay dos Operadores de Identidad
#      - IS
#      - IS NOT

# %%
# IS

# %%
num_1 = 11
num_2 = 55
print("num_1 is num_2", num_1 is num_2)
# Out:
# num_1 is num_2 False

# %%
num_1 = 77
num_2 = 77
print("num_1 is num_2", num_1 is num_2)
# Out:
# num_1 is num_2 True

# %%
# IS NOT

# %%
num_1 = 11
num_2 = 55
print("num_1 is not num_2", num_1 is not num_2)
# Out:
# num_1 is not num_2 True

# %%
num_1 = 77
num_2 = 77
print("num_1 is not num_2", num_1 is not num_2)
# Out:
# num_1 is not num_2 False

# %% [markdown]
# ## Conversión de tipos

# %% [markdown]
# ¿Que es la Conversión de Tipos?
# - Es el proseso de conversion de un tipo de dato a otro tipo de dato
# - Es un paso muy importante para convinar multiples tipos de datos en un formato especifico
# - Hay de dos tipos:
#     - Conversión ImplÍcita: hecha  de forma automatica por el interprete de python
#     - Conversión Explícita:

# %%
# Conversión Implícita

# %%
14+2.0
# Out:
# 16.0

# %%
14+2.0+3
# Out:
# 19.0

# %%
# Conversión Explícita

# %%
int(199.99)
# Out:
# 199

# %%
float(158)
# Out:
# 158.0

# %%
complex(4)
# Out:
# (4+0j)

# %% [markdown]
# ### Conversión int

# %%
int(10.78) # float a int
# Out:
# 10

# %%
int(False) # bool a int
# Out:
# 0

# %%
int(True) # bool a int
# Out:
# 1

# %%
# error
int(5+3j) # complex a int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # error
# ----> 2 int(5+3j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int("120") # string a entero
# Out:
# 120

# %%
# error
int("120.5") # string a entero
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 # error
# ----> 2 int("120.5")
#
# ValueError: invalid literal for int() with base 10: '120.5'

# %% [markdown]
# ### Conversión float

# %%
float(23) # int a float
# Out:
# 23.0

# %%
# error
float(23+3j) # complex a float
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # error
# ----> 2 float(23+3j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float(True) # bool a float
# Out:
# 1.0

# %%
float("843.29") # string a float
# Out:
# 843.29

# %%
float("843") # string a float
# Out:
# 843.0

# %%
# error
float("843t") # string a float
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 # error
# ----> 2 float("843t")
#
# ValueError: could not convert string to float: '843t'

# %%
# error
float("True") # string a float
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 # error
# ----> 2 float("True")
#
# ValueError: could not convert string to float: 'True'

# %% [markdown]
# ### Conversiones complex

# %%
complex(42) # int a complex
# Out:
# (42+0j)

# %%
complex(92.8) # float a complex
# Out:
# (92.8+0j)

# %%
complex(True) # bool a complex
# Out:
# (1+0j)

# %%
complex(False) # bool a complex
# Out:
# 0j

# %%
complex("24") # string a complex
# Out:
# (24+0j)

# %%
complex("24.67") # string a complex
# Out:
# (24.67+0j)

# %%
# error
complex("Backend") # string a complex
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 2
#       1 # error
# ----> 2 complex("Backend")
#
# ValueError: complex() arg is a malformed string

# %%
# error
complex("10c") # string a complex# err
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 2
#       1 # error
# ----> 2 complex("10c")
#
# ValueError: complex() arg is a malformed string

# %%
complex("10j") # string a complex
# Out:
# 10j

# %%
# error
complex("10i") # string a complex# err
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 # error
# ----> 2 complex("10i")
#
# ValueError: complex() arg is a malformed string

# %% [markdown]
# ### Conversiones bool

# %%
bool(0) # int a bool
# Out:
# False

# %%
bool(7) # int a bool
# Out:
# True

# %%
bool(1.8) # float a bool
# Out:
# True

# %%
bool(-1.8) # float a bool
# Out:
# True

# %%
bool(0.0) # float a bool
# Out:
# False

# %%
bool(0+3j) # complex a bool
# Out:
# True

# %%
bool(0+0j) # complex a bool
# Out:
# False

# %%
bool(2+0j) # complex a bool
# Out:
# True

# %%
bool("python") # string a bool
# Out:
# True

# %%
bool(" ") # string a bool
# Out:
# True

# %%
bool("") # string a bool
# Out:
# False

# %%
bool("0") # string a bool
# Out:
# True

# %% [markdown]
# ### Conversiones str

# %%
str(25) # int a str
# Out:
# '25'

# %%
str(36.9) # float a str
# Out:
# '36.9'

# %%
str(6+8j) # complex a str
# Out:
# '(6+8j)'

# %%
str(True) # bool a str
# Out:
# 'True'

# %% [markdown]
# # Funciones Basicas

# %% [markdown]
# ### trunc()

# %%
num_1 = 64.99
num_2 = 64.5
num_3 = 64.51
num_4 = 64.00000000000001
print("num_1: ", num_1)
print("num_2: ", num_2)
print("num_3: ", num_3)
print("num_4: ", num_4)
# Out:
# num_1:  64.99
# num_2:  64.5
# num_3:  64.51
# num_4:  64.00000000000001

# %%
from math import trunc
num_1 = 64.99
num_2 = 64.5
num_3 = 64.51
num_4 = 64.00000000000001
print("trunc (num_1): ", trunc (num_1))
print("trunc (num_2): ", trunc (num_2))
print("trunc (num_3): ", trunc (num_3))
print("trunc (num_4): ", trunc (num_4))
# Out:
# trunc (num_1):  64
# trunc (num_2):  64
# trunc (num_3):  64
# trunc (num_4):  64

# %% [markdown]
# ### round(), ceil() y floor()

# %%
# round
num_1 = 64.99
num_2 = 64.5
num_3 = 64.51
num_4 = 64.00000000000001
print("round (num_1): ", round (num_1))
print("round (num_2): ", round (num_2))
print("round (num_3): ", round (num_3))
print("round (num_4): ", round (num_4))
# Out:
# round (num_1):  65
# round (num_2):  64
# round (num_3):  65
# round (num_4):  64

# %%
# ceil - redondeo hacia arriba
from math import ceil
num_1 = 64.99
num_2 = 64.5
num_3 = 64.51
num_4 = 64.00000000000001
print("ceil (num_1): ", ceil (num_1))
print("ceil (num_2): ", ceil (num_2))
print("ceil (num_3): ", ceil (num_3))
print("ceil (num_4): ", ceil (num_4))
# Out:
# ceil (num_1):  65
# ceil (num_2):  65
# ceil (num_3):  65
# ceil (num_4):  65

# %%
# floor - redondeo hacia abajo
from math import floor
num_1 = 64.99
num_2 = 64.5
num_3 = 64.51
num_4 = 64.00000000000001
print("floor (num_1): ", floor (num_1))
print("floor (num_2): ", floor (num_2))
print("floor (num_3): ", floor (num_3))
print("floor (num_4): ", floor (num_4))
# Out:
# floor (num_1):  64
# floor (num_2):  64
# floor (num_3):  64
# floor (num_4):  64

# %% [markdown]
# ### Funcion %

# %%
num_1 = 64.99
num_2 = 64.5
num_3 = 64.51
num_4 = 64.00000000000001
print("'%.1f' num_1: ", '%.1f' % (num_1))
print("'%.3f' num_2: ", '%.3f' % (num_2))
print("'%.4f' num_3: ", '%.4f' % (num_3))
print("'%.5f' num_4: ", '%.5f' % (num_4))
# Out:
# '%.1f' num_1:  65.0
# '%.3f' num_2:  64.500
# '%.4f' num_3:  64.5100
# '%.5f' num_4:  64.00000

# %% [markdown]
# ### format()

# %%
num_1 = 64.99
num_2 = 64.5
num_3 = 64.51
num_4 = 64.00000000000001
print("'{:.1f}'.format(num_1): ", '{:.1f}'.format(num_1))
print("'{:.3f}'.format(num_2): ", '{:.3f}'.format(num_2))
print("'{:.4f}'.format(num_3): ", '{:.4f}'.format(num_3))
print("'{:.5f}'.format(num_4): ", '{:.5f}'.format(num_4))
# Out:
# '{:.1f}'.format(num_1):  65.0
# '{:.3f}'.format(num_2):  64.500
# '{:.4f}'.format(num_3):  64.5100
# '{:.5f}'.format(num_4):  64.00000
